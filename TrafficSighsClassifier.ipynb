# %% [markdown]
# # LeNet Lab Solution
# ![LeNet Architecture](lenet.png)
# Source: Yan LeCun

# %% [markdown]
# ## Load Data
#
# Load the MNIST data, which comes pre-loaded with TensorFlow.
#
# You do not need to modify this section.

# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("MNIST_data/", reshape=False)
X_train, y_train           = mnist.train.images, mnist.train.labels
X_validation, y_validation = mnist.validation.images, mnist.validation.labels
X_test, y_test             = mnist.test.images, mnist.test.labels

assert(len(X_train) == len(y_train))
assert(len(X_validation) == len(y_validation))
assert(len(X_test) == len(y_test))

print()
print("Image Shape: {}".format(X_train[0].shape))
print()
print("Training Set:   {} samples".format(len(X_train)))
print("Validation Set: {} samples".format(len(X_validation)))
print("Test Set:       {} samples".format(len(X_test)))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
#
# Image Shape: (28, 28, 1)
#
# Training Set:   55000 samples
# Validation Set: 5000 samples
# Test Set:       10000 samples

# %% [markdown]
# The MNIST data that TensorFlow pre-loads comes as 28x28x1 images.
#
# However, the LeNet architecture only accepts 32x32xC images, where C is the number of color channels.
#
# In order to reformat the MNIST data into a shape that LeNet will accept, we pad the data with two rows of zeros on the top and bottom, and two columns of zeros on the left and right (28+2+2 = 32).
#
# You do not need to modify this section.

# %%
import numpy as np

# Pad images with 0s
X_train      = np.pad(X_train, ((0,0),(2,2),(2,2),(0,0)), 'constant')
X_validation = np.pad(X_validation, ((0,0),(2,2),(2,2),(0,0)), 'constant')
X_test       = np.pad(X_test, ((0,0),(2,2),(2,2),(0,0)), 'constant')
    
print("Updated Image Shape: {}".format(X_train[0].shape))
# Out:
# Updated Image Shape: (32, 32, 1)

# %% [markdown]
# ## Visualize Data
#
# View a sample from the dataset.
#
# You do not need to modify this section.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image, cmap="gray")
print(y_train[index])
# Out:
# 1

# %% [markdown]
# ## Preprocess Data
#
# Shuffle the training data.
#
# You do not need to modify this section.

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# ## Setup TensorFlow
# The `EPOCH` and `BATCH_SIZE` values affect the training speed and model accuracy.
#
# You do not need to modify this section.

# %%
import tensorflow as tf

EPOCHS = 10
BATCH_SIZE = 128

# %% [markdown]
# ## SOLUTION: Implement LeNet-5
# Implement the [LeNet-5](http://yann.lecun.com/exdb/lenet/) neural network architecture.
#
# This is the only cell you need to edit.
# ### Input
# The LeNet architecture accepts a 32x32xC image as input, where C is the number of color channels. Since MNIST images are grayscale, C is 1 in this case.
#
# ### Architecture
# **Layer 1: Convolutional.** The output shape should be 28x28x6.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 14x14x6.
#
# **Layer 2: Convolutional.** The output shape should be 10x10x16.
#
# **Activation.** Your choice of activation function.
#
# **Pooling.** The output shape should be 5x5x16.
#
# **Flatten.** Flatten the output shape of the final pooling layer such that it's 1D instead of 3D. The easiest way to do is by using `tf.contrib.layers.flatten`, which is already imported for you.
#
# **Layer 3: Fully Connected.** This should have 120 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 4: Fully Connected.** This should have 84 outputs.
#
# **Activation.** Your choice of activation function.
#
# **Layer 5: Fully Connected (Logits).** This should have 10 outputs.
#
# ### Output
# Return the result of the 2nd fully connected layer.

# %%
from tensorflow.contrib.layers import flatten

# %%
def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 6), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(6))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)

    # SOLUTION: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 10x10x16.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)

    # SOLUTION: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 5x5x16. Output = 400.
    fc0   = flatten(conv2)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(400, 120), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(120))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b
    
    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)

    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(84))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b
    
    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)

    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(84, 10), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(10))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %%
def LeNet_v2(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x64.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 64), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(64))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)

    # SOLUTION: Pooling. Input = 28x28x64. Output = 14x14x64.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 10x10x128.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 64, 128), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(128))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)

    # SOLUTION: Pooling. Input = 10x10x128. Output = 5x5x128.
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 5x5x128. Output = 3200.
    fc0   = flatten(conv2)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 3200. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(3200, 120), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(120))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b
    
    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)

    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(84))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b
    
    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)

    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(84, 10), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(10))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %% [markdown]
# ## Features and Labels
# Train LeNet to classify [MNIST](http://yann.lecun.com/exdb/mnist/) data.
#
# `x` is a placeholder for a batch of input images.
# `y` is a placeholder for a batch of output labels.
#
# You do not need to modify this section.

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 10)

# %% [markdown]
# ## Training Pipeline
# Create a training pipeline that uses the model to classify MNIST data.
#
# You do not need to modify this section.

# %%
rate = 0.001

logits = LeNet_v2(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

# %% [markdown]
# ## Model Evaluation
# Evaluate how well the loss and accuracy of the model for a given dataset.
#
# You do not need to modify this section.

# %%
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# %% [markdown]
# ## Train the Model
# Run the training data through the training pipeline to train the model.
#
# Before each epoch, shuffle the training set.
#
# After each epoch, measure the loss and accuracy of the validation set.
#
# Save the model after training.
#
# You do not need to modify this section.

# %%
import time
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Training...")
    start_total_time = time.time()
    print()
    for i in range(EPOCHS):
        start_epoch_time = time.time()
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_validation, y_validation)
        end_epoch_time = time.time()
        print("EPOCH {}: executed time: {}".format(i+1, end_epoch_time - start_epoch_time))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
    
    end_total_time = time.time()
    print("Executed time is: {}".format(end_total_time - start_total_time))
    saver.save(sess, './lenet_v2')
    print("Model saved")
# Out:
# Training...
#
# EPOCH 1: executed time: 86.2487211227417
# Validation Accuracy = 0.983
#
# EPOCH 2: executed time: 78.5652449131012
# Validation Accuracy = 0.989
#
# EPOCH 3: executed time: 75.82876396179199
# Validation Accuracy = 0.988
#
# EPOCH 4: executed time: 76.14305400848389
# Validation Accuracy = 0.988
#
# EPOCH 5: executed time: 76.16113996505737
# Validation Accuracy = 0.991
#
# EPOCH 6: executed time: 81.81434893608093
# Validation Accuracy = 0.991
#
# EPOCH 7: executed time: 76.52077293395996
# Validation Accuracy = 0.990
#
# EPOCH 8: executed time: 77.67230916023254
# Validation Accuracy = 0.990
#
# EPOCH 9: executed time: 79.61575102806091
# Validation Accuracy = 0.989
#
# EPOCH 10: executed time: 81.59290409088135
# Validation Accuracy = 0.989
#
# EPOCH 11: executed time: 79.52125191688538
# Validation Accuracy = 0.990
#
# EPOCH 12: executed time: 76.19860005378723
# Validation Accuracy = 0.992
#
# EPOCH 13: executed time: 76.12858319282532
# Validation Accuracy = 0.992
#
# EPOCH 14: executed time: 76.73150205612183
# Validation Accuracy = 0.993
#
# EPOCH 15: executed time: 76.259122133255
# Validation Accuracy = 0.990
#
# EPOCH 16: executed time: 76.14029097557068
# Validation Accuracy = 0.992
#
# EPOCH 17: executed time: 76.53536915779114
# Validation Accuracy = 0.991
#
# EPOCH 18: executed time: 76.20835614204407
# Validation Accuracy = 0.993
#
# EPOCH 19: executed time: 75.84640192985535
# Validation Accuracy = 0.992
#
# EPOCH 20: executed time: 75.86010003089905
# Validation Accuracy = 0.992
#
# EPOCH 21: executed time: 75.89312887191772
# Validation Accuracy = 0.992
#
# EPOCH 22: executed time: 76.19101691246033
# Validation Accuracy = 0.993
#
# EPOCH 23: executed time: 75.8602340221405
# Validation Accuracy = 0.991
#
# EPOCH 24: executed time: 75.62411594390869
# Validation Accuracy = 0.990
#
# EPOCH 25: executed time: 76.08772778511047
# Validation Accuracy = 0.993
#
# EPOCH 26: executed time: 75.98435187339783
# Validation Accuracy = 0.992
#
# EPOCH 27: executed time: 75.81708908081055
# Validation Accuracy = 0.992
#
# EPOCH 28: executed time: 75.52102899551392
# Validation Accuracy = 0.993
#
# EPOCH 29: executed time: 75.92449522018433
# Validation Accuracy = 0.992
#
# EPOCH 30: executed time: 75.39220595359802
# Validation Accuracy = 0.993
#
# EPOCH 31: executed time: 75.6486759185791
# Validation Accuracy = 0.989
#
# EPOCH 32: executed time: 75.59235095977783
# Validation Accuracy = 0.992
#
# EPOCH 33: executed time: 74.28207206726074
# Validation Accuracy = 0.990
#
# EPOCH 34: executed time: 75.86573100090027
# Validation Accuracy = 0.993
#
# EPOCH 35: executed time: 75.48730707168579
# Validation Accuracy = 0.992
#
# EPOCH 36: executed time: 75.54460787773132
# Validation Accuracy = 0.992
#
# EPOCH 37: executed time: 75.69032597541809
# Validation Accuracy = 0.992
#
# EPOCH 38: executed time: 75.49790096282959
# Validation Accuracy = 0.991
#
# EPOCH 39: executed time: 75.93429613113403
# Validation Accuracy = 0.992
#
# EPOCH 40: executed time: 75.79314088821411
# Validation Accuracy = 0.993
#
# EPOCH 41: executed time: 75.84004092216492
# Validation Accuracy = 0.993
#
# EPOCH 42: executed time: 76.02006697654724
# Validation Accuracy = 0.991
#
# EPOCH 43: executed time: 75.71993207931519
# Validation Accuracy = 0.991
#
# EPOCH 44: executed time: 75.57355904579163
# Validation Accuracy = 0.993
#
# EPOCH 45: executed time: 75.97888612747192
# Validation Accuracy = 0.993
#
# EPOCH 46: executed time: 75.61408591270447
# Validation Accuracy = 0.994
#
# EPOCH 47: executed time: 75.64388704299927
# Validation Accuracy = 0.994
#
# EPOCH 48: executed time: 75.62597489356995
# Validation Accuracy = 0.994
#
# EPOCH 49: executed time: 76.08642983436584
# Validation Accuracy = 0.994
#
# EPOCH 50: executed time: 76.25270700454712
# Validation Accuracy = 0.994
#
# EPOCH 51: executed time: 75.85044598579407
# Validation Accuracy = 0.994
#
# EPOCH 52: executed time: 75.83370089530945
# Validation Accuracy = 0.994
#
# EPOCH 53: executed time: 76.21984696388245
# Validation Accuracy = 0.994
#
# EPOCH 54: executed time: 75.62237215042114
# Validation Accuracy = 0.994
#
# EPOCH 55: executed time: 75.76285314559937
# Validation Accuracy = 0.994
#
# EPOCH 56: executed time: 75.9443199634552
# Validation Accuracy = 0.994
#
# EPOCH 57: executed time: 76.02207803726196
# Validation Accuracy = 0.994
#
# EPOCH 58: executed time: 75.64552211761475
# Validation Accuracy = 0.994
#
# EPOCH 59: executed time: 75.85623097419739
# Validation Accuracy = 0.994
#
# EPOCH 60: executed time: 75.99089002609253
# Validation Accuracy = 0.994
#
# EPOCH 61: executed time: 75.89409613609314
# Validation Accuracy = 0.994
#
# EPOCH 62: executed time: 76.2018711566925
# Validation Accuracy = 0.994
#
# EPOCH 63: executed time: 75.67466616630554
# Validation Accuracy = 0.994
#
# EPOCH 64: executed time: 75.6045548915863
# Validation Accuracy = 0.994
#
# EPOCH 65: executed time: 75.82052683830261
# Validation Accuracy = 0.994
#
# EPOCH 66: executed time: 75.74200892448425
# Validation Accuracy = 0.994
#
# EPOCH 67: executed time: 75.92291307449341
# Validation Accuracy = 0.994
#
# EPOCH 68: executed time: 75.7168390750885
# Validation Accuracy = 0.994
#
# EPOCH 69: executed time: 76.1454381942749
# Validation Accuracy = 0.994
#
# EPOCH 70: executed time: 75.79310417175293
# Validation Accuracy = 0.994
#
# EPOCH 71: executed time: 76.15299201011658
# Validation Accuracy = 0.994
#
# EPOCH 72: executed time: 75.90567398071289
# Validation Accuracy = 0.994
#
# EPOCH 73: executed time: 84.39115285873413
# Validation Accuracy = 0.994
#
# EPOCH 74: executed time: 82.75209093093872
# Validation Accuracy = 0.994
#
# EPOCH 75: executed time: 77.88618493080139
# Validation Accuracy = 0.994
#
# EPOCH 76: executed time: 78.15158700942993
# Validation Accuracy = 0.994
#
# EPOCH 77: executed time: 80.1871509552002
# Validation Accuracy = 0.994
#
# EPOCH 78: executed time: 82.59545302391052
# Validation Accuracy = 0.994
#
# EPOCH 79: executed time: 75.88299298286438
# Validation Accuracy = 0.994
#
# EPOCH 80: executed time: 75.82006788253784
# Validation Accuracy = 0.994
#
# EPOCH 81: executed time: 75.99543309211731
# Validation Accuracy = 0.994
#
# EPOCH 82: executed time: 76.11576890945435
# Validation Accuracy = 0.994
#
# EPOCH 83: executed time: 75.9885880947113
# Validation Accuracy = 0.994
#
# EPOCH 84: executed time: 76.09531903266907
# Validation Accuracy = 0.994
#
# EPOCH 85: executed time: 75.83629012107849
# Validation Accuracy = 0.994
#
# EPOCH 86: executed time: 75.8347909450531
# Validation Accuracy = 0.994
#
# EPOCH 87: executed time: 75.88727903366089
# Validation Accuracy = 0.994
#
# EPOCH 88: executed time: 76.14585208892822
# Validation Accuracy = 0.994
#
# EPOCH 89: executed time: 75.98904800415039
# Validation Accuracy = 0.994
#
# EPOCH 90: executed time: 75.98463797569275
# Validation Accuracy = 0.994
#
# EPOCH 91: executed time: 76.30414509773254
# Validation Accuracy = 0.994
#
# EPOCH 92: executed time: 76.2127571105957
# Validation Accuracy = 0.994
#
# EPOCH 93: executed time: 75.97579312324524
# Validation Accuracy = 0.994
#
# EPOCH 94: executed time: 76.07889080047607
# Validation Accuracy = 0.994
#
# EPOCH 95: executed time: 79.05717992782593
# Validation Accuracy = 0.994
#
# EPOCH 96: executed time: 83.76658487319946
# Validation Accuracy = 0.994
#
# EPOCH 97: executed time: 76.69372797012329
# Validation Accuracy = 0.994
#
# EPOCH 98: executed time: 77.08182191848755
# Validation Accuracy = 0.994
#
# EPOCH 99: executed time: 76.58692407608032
# Validation Accuracy = 0.994
#
# EPOCH 100: executed time: 76.86003494262695
# Validation Accuracy = 0.994
#
# Executed time is: 7669.069603919983
# Model saved

# %% [markdown]
# ## Evaluate the Model
# Once you are completely satisfied with your model, evaluate the performance of the model on the test set.
#
# Be sure to only do this once!
#
# If you were to measure the performance of your trained model on the test set, then improve your model, and then measure the performance of your model on the test set again, that would invalidate your test results. You wouldn't get a true measure of how well your model would perform against real data.
#
# You do not need to modify this section.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))

    test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet_v2
# Test Accuracy = 0.994
